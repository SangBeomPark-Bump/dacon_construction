# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 한글 폰트 문제 해결 
# matplotlib은 한글 폰트를 지원하지 않음
# os정보
import platform

# font_manager : 폰트 관리 모듈
# rc : 폰트 변경 모듈
from matplotlib import font_manager, rc
# unicode 설정
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

# %%
train_data =  pd.read_csv('../data/train_preprocessed.csv')

train_data.head()
# Out:
#             ID                 발생일시 사고인지 시간  날씨    기온    습도 대분류(공사장위치)  \
# 0  TRAIN_00000  2023-12-31 12:44:00    정규작업  맑음   1.0  30.0        건축
# 1  TRAIN_00001  2023-12-30 15:35:00    정규작업  맑음  10.0  90.0        토목
# 2  TRAIN_00002  2023-12-30 14:30:00    정규작업  맑음  14.0  70.0        건축
# 3  TRAIN_00003  2023-12-30 12:00:00    휴일근무  흐림  12.0  55.0        토목
# 4  TRAIN_00004  2023-12-30 10:00:00    정규작업  맑음   0.0  10.0        건축
#
#   중분류(공사장위치) 소분류(공사장위치) 극소분류(공사장위치)  ...  대분류(사고객체) 소분류(사고객체)   작업프로세스  \
# 0       건축물      근린생활시설         NaN  ...      건설자재         철근     설치작업
# 1        터널        철도터널         NaN  ...      건설자재         볼트     운반작업
# 2       건축물        업무시설         NaN  ...        기타         기타  형틀 및 목공
# 3        하천          기타         NaN  ...        부재      교각 기초     조립작업
# 4       건축물        공동주택         NaN  ...        기타      건설폐기물     해체작업
#
#   대분류(장소)   소분류(장소) 기타분류(장소) 대분류(다친위치) 소분류(다친위치)  \
# 0  근린생활시설        내부      NaN        철근        고소
# 1    철도터널        내부      NaN        볼트        바닥
# 2    업무시설        내부      NaN        기타        바닥
# 3      기타  동산교 신축구간      NaN     교각 기초        바닥
# 4    공동주택        내부      NaN     건설폐기물        바닥
#
#                                                 사고원인  \
# 0  고소작업 중 추락 위험이 있음에도 불구하고, 안전난간대, 안전고리 착용 등 안전장치...
# 1                                                부주의
# 2                               3층 슬라브 작업시 이동중  미끄러짐
# 3  교각 기초철근 조립 중 강한 바람에 의해 기둥측 주철근이 균형을 잃고 전도되어, 하...
# 4                                           근로자의 부주의
#
#                                      재발방지대책 및 향후조치계획
# 0                      고소작업 시 추락 위험이 있는 부위에 안전장비 설치.
# 1                              재발 방지 대책 마련과 안전교육 실시.
# 2  현장자재 정리와 안전관리 철저를 통한 재발 방지 대책 및 공문 발송을 통한 향후 조...
# 3  위험성 평가 및 교육을 통해 작업장 내 위험요인과 안전수칙을 근로자에게 전파하고, ...
# 4  자재 정리 작업 시 세부 작업 방법에 대한 교육 실시와 작업 구간 이동 경로 점검 ...
#
# [5 rows x 27 columns]
